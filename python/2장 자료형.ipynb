# %%
## 연산자를 사용해서 숫자 14를 3으로 나누었을 때 몫과 나머지를 확인해 보자.
print('몫 :', 14 // 3)
print('나머지:', 14 % 3)
# Out:
# 몫 : 4
# 나머지: 2

# %%
## format 함수 또는 f 문자열 포매팅을 사용해 !!!python!!!문자열을 출력해보자
print('{0:!^12}'.format('python'))
print(f'{"python":!^12}')
# Out:
# !!!python!!!
# !!!python!!!

# %%
## A=[1,2,3,4,5] 리스트에서 슬라이싱 기법을 사용하여 리스트[2,3]를 만들어보자
A=[1,2,3,4,5]
A[1:3]
# Out:
# [2, 3]

# %%
#(1,2,3)이라는 튜플에 값 4를 추가하여 (1,2,3,4)를 만들어 출력해 보자.
(1,2,3)+(4,)
# Out:
# (1, 2, 3, 4)

# %%
# 딕셔너리 만들기
dic = {'name':'홍길동', 'birth':1128, 'age':30}

# %%
# 예제를 실행하고 그 결과를 설명해 보자
a = [1,2,3]
b = [1,2,3]
a is b
# 변수 a와 b는 서로 다른 메모리를 가리키므로 False
# Out:
# False

# %% [markdown]
# ### 연습문제

# %%
# 1. 평균점수
(80 + 75 + 55) / 3
# Out:
# 70.0

# %%
# 2. 자연수 12이 홀수인지 짝수인지 판별할 수 있는 방법에 대해 말해 보자
13 % 2
# Out:
# 1

# %%
# 3. 주민등록번호는 881120-1068234 이다. 주민등록번호를 연월일(YYYYMMDD)부분과 그 뒤의 숫자 부분으로 나누어 출력해보자
pin = "8811220-1068234"
yyyymmdd = pin[:7]
num = pin[8:]
print(yyyymmdd)
print(num)
# Out:
# 8811220
# 1068234

# %%
# 4. 주민등록번호 뒷자리의 맨 첫 번째 숫자는 성별을 나타낸다. 주민등록번호에서 성별을 나타내는 숫자를 출력해보자
pin = "881120-1068234"
print(pin[pin.index('-')+1])
# Out:
# 1

# %%
# 5. 다음과 같은 문자열 a:b:c:d가 있다. 문자열의 replace 함수를 사용하여 a#b#c#d로 바꿔서 출력해 보자.
a = "a:b:c:d"
b = a.replace(':','#')
print(b)
# Out:
# a#b#c#d

# %%
# 6. [1,3,5,4,2]리스트를 [5,4,3,2,1]로 만들어보자
a = [1,3,5,4,2,]
a.sort()
a.reverse()
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
# 7
a = ['Life','is','too','short']
result = ' '.join(a)
print(result)
# Out:
# Life is too short

# %%
# 8. (1,2,3) 튜플에 값 4를 추가하여 (1,2,3,4)를 만들어 출력해 보자.
a = (1,2,3)
a = a + (4,)
print(a)
# Out:
# (1, 2, 3, 4)

# %%
# 9. 오류찾기
a[[1]] = 'python'
#오류가 발생하는 이유는 딕셔너리의 키로는 변하는(mutable) 값을 사용할 수 없기 때문이다. 
#위 예에서 키로 사용된 [1]은 리스트이므로 변하는 값이다. 
#다른 예에서 키로 사용된 문자열, 튜플, 숫자는 변하지 않는(immutable) 값이므로 딕셔너리의 키로 사용이 가능하다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e951673a9d4a> in <module>
#       1 # 9. 오류찾기
# ----> 2 a[[1]] = 'python'
#       3 #오류가 발생하는 이유는 딕셔너리의 키로는 변하는(mutable) 값을 사용할 수 없기 때문이다.
#       4 #위 예에서 키로 사용된 [1]은 리스트이므로 변하는 값이다.
#       5 #다른 예에서 키로 사용된 문자열, 튜플, 숫자는 변하지 않는(immutable) 값이므로 딕셔너리의 키로 사용이 가능하다.
#
# TypeError: list indices must be integers or slices, not list

# %%
# 10. 딕셔너리 a에서 'B'에 해당되는 값을 추출해 보자
a = {'A':90, 'B':80, 'C':70}
result = a.pop('B')
print(a)
print(result)
# Out:
# {'A': 90, 'C': 70}
# 80

# %%
# 11. a 리스트에서 중복 숫자를 제거해 보자
a = [1,1,1,2,2,3,3,3,4,4,5]
aSet = set(a)
b = list(aSet)
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 12. 파이썬은 동일한 값에 여러 개의 변수를 선언할 수 있다. 다음과 같이 a, b 변수를 선언한 후 a의 두 번째 요소값을 변경하면 b 값은 어떻게 될까?
a = b = [1,2,3]
a[1] = 4
print(b)
# 동일한 주소값을 갖기때문에 동시에 변경된다.
# Out:
# [1, 4, 3]
