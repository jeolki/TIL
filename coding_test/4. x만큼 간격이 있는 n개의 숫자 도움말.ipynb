# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(x, n):
    answer = []
    sum = 0
    for i in range(n):
        sum += x
        answer.append(sum)
    
    return answer

# %%
x = 2
n = 5
print(solution(x,n))
# Out:
# [2, 4, 6, 8, 10]

# %%
def solution(x, n):
    return [i * x + x for i in range(n)]
